# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./Datasets/Heart_Disease_UCI/heart.csv')
#https://www.kaggle.com/ronitf/heart-disease-uci
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.notnull().count()
# Out:
# age         303
# sex         303
# cp          303
# trestbps    303
# chol        303
# fbs         303
# restecg     303
# thalach     303
# exang       303
# oldpeak     303
# slope       303
# ca          303
# thal        303
# target      303
# dtype: int64

# %%
data.describe()
data.dtypes
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data.corr().sort_values(by='exang', axis=1)
data.describe().sort_values(by='std', axis=1)
# Out:
#             target        cp   thalach     slope   restecg       fbs  \
# age      -0.225439 -0.068653 -0.398522 -0.168814 -0.116211  0.121308
# sex      -0.280937 -0.049353 -0.044020 -0.030711 -0.058196  0.045032
# cp        0.433798  1.000000  0.295762  0.119717  0.044421  0.094444
# trestbps -0.144931  0.047608 -0.046698 -0.121475 -0.114103  0.177531
# chol     -0.085239 -0.076904 -0.009940 -0.004038 -0.151040  0.013294
# fbs      -0.028046  0.094444 -0.008567 -0.059894 -0.084189  1.000000
# restecg   0.137230  0.044421  0.044123  0.093045  1.000000 -0.084189
# thalach   0.421741  0.295762  1.000000  0.386784  0.044123 -0.008567
# exang    -0.436757 -0.394280 -0.378812 -0.257748 -0.070733  0.025665
# oldpeak  -0.430696 -0.149230 -0.344187 -0.577537 -0.058770  0.005747
# slope     0.345877  0.119717  0.386784  1.000000  0.093045 -0.059894
# ca       -0.391724 -0.181053 -0.213177 -0.080155 -0.072042  0.137979
# thal     -0.344029 -0.161736 -0.096439 -0.104764 -0.011981 -0.032019
# target    1.000000  0.433798  0.421741  0.345877  0.137230 -0.028046
#
#               chol  trestbps       age        ca       sex      thal  \
# age       0.213678  0.279351  1.000000  0.276326 -0.098447  0.068001
# sex      -0.197912 -0.056769 -0.098447  0.118261  1.000000  0.210041
# cp       -0.076904  0.047608 -0.068653 -0.181053 -0.049353 -0.161736
# trestbps  0.123174  1.000000  0.279351  0.101389 -0.056769  0.062210
# chol      1.000000  0.123174  0.213678  0.070511 -0.197912  0.098803
# fbs       0.013294  0.177531  0.121308  0.137979  0.045032 -0.032019
# restecg  -0.151040 -0.114103 -0.116211 -0.072042 -0.058196 -0.011981
# thalach  -0.009940 -0.046698 -0.398522 -0.213177 -0.044020 -0.096439
# exang     0.067023  0.067616  0.096801  0.115739  0.141664  0.206754
# oldpeak   0.053952  0.193216  0.210013  0.222682  0.096093  0.210244
# slope    -0.004038 -0.121475 -0.168814 -0.080155 -0.030711 -0.104764
# ca        0.070511  0.101389  0.276326  1.000000  0.118261  0.151832
# thal      0.098803  0.062210  0.068001  0.151832  0.210041  1.000000
# target   -0.085239 -0.144931 -0.225439 -0.391724 -0.280937 -0.344029
#
#            oldpeak     exang
# age       0.210013  0.096801
# sex       0.096093  0.141664
# cp       -0.149230 -0.394280
# trestbps  0.193216  0.067616
# chol      0.053952  0.067023
# fbs       0.005747  0.025665
# restecg  -0.058770 -0.070733
# thalach  -0.344187 -0.378812
# exang     0.288223  1.000000
# oldpeak   1.000000  0.288223
# slope    -0.577537 -0.257748
# ca        0.222682  0.115739
# thal      0.210244  0.206754
# target   -0.430696 -0.436757
#               fbs         sex       exang      target     restecg        thal  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.148515    0.683168    0.326733    0.544554    0.528053    2.313531
# std      0.356198    0.466011    0.469794    0.498835    0.525860    0.612277
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    2.000000
# 50%      0.000000    1.000000    0.000000    1.000000    1.000000    2.000000
# 75%      0.000000    1.000000    1.000000    1.000000    1.000000    3.000000
# max      1.000000    1.000000    1.000000    1.000000    2.000000    3.000000
#
#             slope          ca          cp     oldpeak         age    trestbps  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     1.399340    0.729373    0.966997    1.039604   54.366337  131.623762
# std      0.616226    1.022606    1.032052    1.161075    9.082101   17.538143
# min      0.000000    0.000000    0.000000    0.000000   29.000000   94.000000
# 25%      1.000000    0.000000    0.000000    0.000000   47.500000  120.000000
# 50%      1.000000    0.000000    1.000000    0.800000   55.000000  130.000000
# 75%      2.000000    1.000000    2.000000    1.600000   61.000000  140.000000
# max      2.000000    4.000000    3.000000    6.200000   77.000000  200.000000
#
#           thalach        chol
# count  303.000000  303.000000
# mean   149.646865  246.264026
# std     22.905161   51.830751
# min     71.000000  126.000000
# 25%    133.500000  211.000000
# 50%    153.000000  240.000000
# 75%    166.000000  274.500000
# max    202.000000  564.000000

# %%
data.var()
# Out:
# age           82.484558
# sex            0.217166
# cp             1.065132
# trestbps     307.586453
# chol        2686.426748
# fbs            0.126877
# restecg        0.276528
# thalach      524.646406
# exang          0.220707
# oldpeak        1.348095
# slope          0.379735
# ca             1.045724
# thal           0.374883
# target         0.248836
# dtype: float64

# %%
local_columns = ['sex', 'ca', 'cp', 'oldpeak', 'age', 'target']
sns.pairplot(data[local_columns], hue='target')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
d_tree_c = DecisionTreeClassifier()

# %%
columns_for_d_tree_c = \
    ['age', 'cp', 'trestbps', 'chol', 'restecg', 'thalach', 'oldpeak', 'slope', 'ca', 'thal']
X_train, X_test, Y_train, Y_test = train_test_split(data[columns_for_d_tree_c], data['target'], stratify=data['target'])

# %%
d_tree_c.fit(X_train, Y_train)
tree_prediction = d_tree_c.predict(X_test)
print(classification_report(Y_test, tree_prediction))
print(confusion_matrix(Y_test, tree_prediction))
# Out:
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69        35
#            1       0.73      0.73      0.73        41
#
#     accuracy                           0.71        76
#    macro avg       0.71      0.71      0.71        76
# weighted avg       0.71      0.71      0.71        76
#
# [[24 11]
#  [11 30]]

# %%
#fig, ax = plt.subplots(figsize=(20, 18), dpi=120)
plt.figure(figsize=(30, 30), dpi= 120)
plot_tree(d_tree_c, filled=True)
# Out:
# [Text(1217.3958333333333, 2582.1, 'X[1] <= 0.5\ngini = 0.496\nsamples = 227\nvalue = [103, 124]'),
#  Text(620.0, 2310.3, 'X[8] <= 0.5\ngini = 0.422\nsamples = 106\nvalue = [74, 32]'),
#  Text(387.5, 2038.5, 'X[6] <= 0.8\ngini = 0.49\nsamples = 49\nvalue = [21, 28]'),
#  Text(258.3333333333333, 1766.6999999999998, 'X[3] <= 272.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(155.0, 1494.8999999999999, 'X[2] <= 158.0\ngini = 0.188\nsamples = 19\nvalue = [2, 17]'),
#  Text(103.33333333333333, 1223.1, 'X[0] <= 62.5\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(51.666666666666664, 951.3, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(155.0, 951.3, 'X[5] <= 138.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(103.33333333333333, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(206.66666666666666, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(206.66666666666666, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(361.66666666666663, 1494.8999999999999, 'X[4] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(310.0, 1223.1, 'X[5] <= 153.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(258.3333333333333, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(361.66666666666663, 951.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(413.3333333333333, 1223.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(516.6666666666666, 1766.6999999999998, 'X[2] <= 116.5\ngini = 0.444\nsamples = 24\nvalue = [16, 8]'),
#  Text(465.0, 1494.8999999999999, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(568.3333333333333, 1494.8999999999999, 'X[7] <= 1.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(516.6666666666666, 1223.1, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(620.0, 1223.1, 'X[3] <= 273.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(568.3333333333333, 951.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(671.6666666666666, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(852.5, 2038.5, 'X[2] <= 108.0\ngini = 0.131\nsamples = 57\nvalue = [53, 4]'),
#  Text(723.3333333333333, 1766.6999999999998, 'X[6] <= 0.6\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(671.6666666666666, 1494.8999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(775.0, 1494.8999999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(981.6666666666666, 1766.6999999999998, 'X[3] <= 301.5\ngini = 0.103\nsamples = 55\nvalue = [52, 3]'),
#  Text(878.3333333333333, 1494.8999999999999, 'X[5] <= 105.5\ngini = 0.043\nsamples = 45\nvalue = [44, 1]'),
#  Text(826.6666666666666, 1223.1, 'X[6] <= 0.6\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(775.0, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(878.3333333333333, 951.3, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(930.0, 1223.1, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(1085.0, 1494.8999999999999, 'X[3] <= 303.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(1033.3333333333333, 1223.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1136.6666666666665, 1223.1, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(1814.7916666666665, 2310.3, 'X[0] <= 56.5\ngini = 0.364\nsamples = 121\nvalue = [29, 92]'),
#  Text(1420.8333333333333, 2038.5, 'X[5] <= 148.0\ngini = 0.229\nsamples = 76\nvalue = [10, 66]'),
#  Text(1240.0, 1766.6999999999998, 'X[6] <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(1188.3333333333333, 1494.8999999999999, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1291.6666666666665, 1494.8999999999999, 'X[5] <= 125.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(1240.0, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1343.3333333333333, 1223.1, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(1601.6666666666665, 1766.6999999999998, 'X[9] <= 2.5\ngini = 0.14\nsamples = 66\nvalue = [5, 61]'),
#  Text(1498.3333333333333, 1494.8999999999999, 'X[5] <= 152.5\ngini = 0.037\nsamples = 53\nvalue = [1, 52]'),
#  Text(1446.6666666666665, 1223.1, 'X[2] <= 113.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(1395.0, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1498.3333333333333, 951.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(1550.0, 1223.1, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(1705.0, 1494.8999999999999, 'X[5] <= 180.0\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(1653.3333333333333, 1223.1, 'X[7] <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(1601.6666666666665, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1705.0, 951.3, 'X[8] <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(1653.3333333333333, 679.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(1756.6666666666665, 679.5, 'X[0] <= 50.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(1705.0, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1808.3333333333333, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1756.6666666666665, 1223.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2208.75, 2038.5, 'X[5] <= 113.5\ngini = 0.488\nsamples = 45\nvalue = [19, 26]'),
#  Text(2157.083333333333, 1766.6999999999998, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2260.4166666666665, 1766.6999999999998, 'X[0] <= 61.5\ngini = 0.472\nsamples = 42\nvalue = [16, 26]'),
#  Text(1963.3333333333333, 1494.8999999999999, 'X[3] <= 224.5\ngini = 0.494\nsamples = 18\nvalue = [10, 8]'),
#  Text(1860.0, 1223.1, 'X[0] <= 59.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(1808.3333333333333, 951.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(1911.6666666666665, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2066.6666666666665, 1223.1, 'X[6] <= 0.65\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(2015.0, 951.3, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(2118.333333333333, 951.3, 'X[2] <= 142.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(2066.6666666666665, 679.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2170.0, 679.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(2557.5, 1494.8999999999999, 'X[5] <= 157.5\ngini = 0.375\nsamples = 24\nvalue = [6, 18]'),
#  Text(2428.333333333333, 1223.1, 'X[8] <= 2.5\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(2325.0, 951.3, 'X[2] <= 175.0\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(2273.333333333333, 679.5, 'X[9] <= 2.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(2221.6666666666665, 407.6999999999998, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(2325.0, 407.6999999999998, 'X[3] <= 219.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(2273.333333333333, 135.9000000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2376.6666666666665, 135.9000000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(2376.6666666666665, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2531.6666666666665, 951.3, 'X[3] <= 238.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(2480.0, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2583.333333333333, 679.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2686.6666666666665, 1223.1, 'X[8] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(2635.0, 951.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2738.333333333333, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
#columns_for_d_tree_c
for i in np.argsort(d_tree_c.feature_importances_):
    print(columns_for_d_tree_c[i], '--->', d_tree_c.feature_importances_[i])
# Out:
# restecg ---> 0.013329940494832446
# thal ---> 0.018875653350393103
# slope ---> 0.04465848963866832
# age ---> 0.09110025621402183
# chol ---> 0.10836157368765706
# thalach ---> 0.11936315659483444
# oldpeak ---> 0.11980019536784337
# trestbps ---> 0.12272282646269757
# ca ---> 0.15072860173507038
# cp ---> 0.2110593064539814

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
