# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('./Datasets/Heart_Failure_Prediction/heart_failure_clinical_records_dataset.csv')
data.columns
data.dtypes
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
data.notnull().count()
data.describe()
# Out:
# age                         299
# anaemia                     299
# creatinine_phosphokinase    299
# diabetes                    299
# ejection_fraction           299
# high_blood_pressure         299
# platelets                   299
# serum_creatinine            299
# serum_sodium                299
# sex                         299
# smoking                     299
# time                        299
# DEATH_EVENT                 299
# dtype: int64
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
#sns.pairplot(data, hue='DEATH_EVENT')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
tree = DecisionTreeClassifier()

# %%
col_for_tree = ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time']
X_train, X_test, Y_train, Y_test = train_test_split(data[col_for_tree], \
                                                    data['DEATH_EVENT'], stratify=data['DEATH_EVENT'])

# %%
tree.fit(X_train, Y_train)
tree_prediction = tree.predict(X_test)
print(classification_report(Y_test, tree_prediction))
print(confusion_matrix(Y_test, tree_prediction))
# Out:
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90        51
#            1       0.77      0.83      0.80        24
#
#     accuracy                           0.87        75
#    macro avg       0.84      0.86      0.85        75
# weighted avg       0.87      0.87      0.87        75
#
# [[45  6]
#  [ 4 20]]

# %%
plt.figure(figsize=(30, 30), dpi= 120)
plot_tree(tree, filled=True, class_names=True)
# Out:
# [Text(1164.375, 2582.1, 'X[11] <= 67.0\ngini = 0.436\nsamples = 224\nvalue = [152, 72]\nclass = y[0]'),
#  Text(360.0, 2310.3, 'X[2] <= 80.5\ngini = 0.282\nsamples = 53\nvalue = [9, 44]\nclass = y[1]'),
#  Text(180.0, 2038.5, 'X[8] <= 134.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]\nclass = y[1]'),
#  Text(90.0, 1766.6999999999998, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = y[1]'),
#  Text(270.0, 1766.6999999999998, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = y[0]'),
#  Text(540.0, 2038.5, 'X[11] <= 28.5\ngini = 0.201\nsamples = 44\nvalue = [5, 39]\nclass = y[1]'),
#  Text(450.0, 1766.6999999999998, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]\nclass = y[1]'),
#  Text(630.0, 1766.6999999999998, 'X[8] <= 139.5\ngini = 0.32\nsamples = 25\nvalue = [5, 20]\nclass = y[1]'),
#  Text(540.0, 1494.8999999999999, 'X[5] <= 0.5\ngini = 0.43\nsamples = 16\nvalue = [5, 11]\nclass = y[1]'),
#  Text(360.0, 1223.1, 'X[8] <= 136.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = y[0]'),
#  Text(270.0, 951.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = y[1]'),
#  Text(450.0, 951.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = y[0]'),
#  Text(720.0, 1223.1, 'X[4] <= 47.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = y[1]'),
#  Text(630.0, 951.3, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = y[1]'),
#  Text(810.0, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = y[0]'),
#  Text(720.0, 1494.8999999999999, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = y[1]'),
#  Text(1968.75, 2310.3, 'X[7] <= 1.55\ngini = 0.274\nsamples = 171\nvalue = [143, 28]\nclass = y[0]'),
#  Text(1597.5, 2038.5, 'X[0] <= 79.0\ngini = 0.162\nsamples = 135\nvalue = [123, 12]\nclass = y[0]'),
#  Text(1305.0, 1766.6999999999998, 'X[4] <= 27.5\ngini = 0.129\nsamples = 130\nvalue = [121, 9]\nclass = y[0]'),
#  Text(990.0, 1494.8999999999999, 'X[11] <= 78.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]\nclass = y[0]'),
#  Text(900.0, 1223.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = y[1]'),
#  Text(1080.0, 1223.1, 'X[8] <= 130.5\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = y[0]'),
#  Text(990.0, 951.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(1170.0, 951.3, 'X[10] <= 0.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]\nclass = y[0]'),
#  Text(1080.0, 679.5, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = y[0]'),
#  Text(1260.0, 679.5, 'X[11] <= 179.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = y[0]'),
#  Text(1170.0, 407.6999999999998, 'X[0] <= 54.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = y[1]'),
#  Text(1080.0, 135.9000000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = y[0]'),
#  Text(1260.0, 135.9000000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = y[1]'),
#  Text(1350.0, 407.6999999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = y[0]'),
#  Text(1620.0, 1494.8999999999999, 'X[6] <= 98500.0\ngini = 0.052\nsamples = 113\nvalue = [110, 3]\nclass = y[0]'),
#  Text(1530.0, 1223.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(1710.0, 1223.1, 'X[7] <= 0.65\ngini = 0.035\nsamples = 112\nvalue = [110, 2]\nclass = y[0]'),
#  Text(1530.0, 951.3, 'X[6] <= 218000.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = y[0]'),
#  Text(1440.0, 679.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(1620.0, 679.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = y[0]'),
#  Text(1890.0, 951.3, 'X[6] <= 343500.0\ngini = 0.018\nsamples = 109\nvalue = [108, 1]\nclass = y[0]'),
#  Text(1800.0, 679.5, 'gini = 0.0\nsamples = 96\nvalue = [96, 0]\nclass = y[0]'),
#  Text(1980.0, 679.5, 'X[6] <= 358000.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = y[0]'),
#  Text(1890.0, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(2070.0, 407.6999999999998, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = y[0]'),
#  Text(1890.0, 1766.6999999999998, 'X[8] <= 135.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = y[1]'),
#  Text(1800.0, 1494.8999999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = y[1]'),
#  Text(1980.0, 1494.8999999999999, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = y[0]'),
#  Text(2340.0, 2038.5, 'X[4] <= 22.5\ngini = 0.494\nsamples = 36\nvalue = [20, 16]\nclass = y[0]'),
#  Text(2250.0, 1766.6999999999998, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = y[1]'),
#  Text(2430.0, 1766.6999999999998, 'X[11] <= 210.0\ngini = 0.458\nsamples = 31\nvalue = [20, 11]\nclass = y[0]'),
#  Text(2340.0, 1494.8999999999999, 'X[2] <= 72.5\ngini = 0.499\nsamples = 23\nvalue = [12, 11]\nclass = y[0]'),
#  Text(2250.0, 1223.1, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = y[0]'),
#  Text(2430.0, 1223.1, 'X[3] <= 0.5\ngini = 0.475\nsamples = 18\nvalue = [7, 11]\nclass = y[1]'),
#  Text(2250.0, 951.3, 'X[2] <= 614.0\ngini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = y[1]'),
#  Text(2160.0, 679.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = y[1]'),
#  Text(2340.0, 679.5, 'X[6] <= 321500.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = y[0]'),
#  Text(2250.0, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = y[0]'),
#  Text(2430.0, 407.6999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = y[1]'),
#  Text(2610.0, 951.3, 'X[2] <= 181.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = y[0]'),
#  Text(2520.0, 679.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = y[1]'),
#  Text(2700.0, 679.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = y[0]'),
#  Text(2520.0, 1494.8999999999999, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = y[0]')]

# %%
for i in np.argsort(tree.feature_importances_):
    print(data.columns[i], '--->', tree.feature_importances_[i])
# Out:
# anaemia ---> 0.0
# sex ---> 0.0
# high_blood_pressure ---> 0.017076835607537366
# smoking ---> 0.01754385964912282
# diabetes ---> 0.038434048083170885
# age ---> 0.0431136602189233
# platelets ---> 0.06372784900376205
# serum_creatinine ---> 0.07981997283567857
# creatinine_phosphokinase ---> 0.08553529989240878
# ejection_fraction ---> 0.08709514082960762
# serum_sodium ---> 0.12843973359324234
# time ---> 0.4392136002865463
